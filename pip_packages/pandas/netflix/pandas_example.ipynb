# %%
import pandas as pd

# %%
# Load data from a CSV file
df = pd.read_csv("netflix_titles.csv")

# %%
# Number of rows and columns
df.shape
# Out:
# (8807, 12)

# %%
# show first 2 rows
print(df.head(2))
# show last 2 rows
print(df.tail(2))
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#      show_id   type   title      director  \
# 8805   s8806  Movie    Zoom  Peter Hewitt
# ...

# %%
# show all the column names
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# show first 5 rows of a specific column
print(df["title"][0:5])
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
# show first 5 rows of multiple columns
print(df[["title", "director"]][0:5])
# Out:
#                    title         director
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              NaN
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans              NaN
# 4           Kota Factory              NaN

# %%
# select rows based on a condition
df.loc[df["director"] == "Peter Jackson"]
# Out:
#      show_id   type                                          title  \
# 950     s951  Movie                               The Lovely Bones
# 8404   s8405  Movie  The Lord of the Rings: The Return of the King
# 8405   s8406  Movie          The Lord of the Rings: The Two Towers
#
#            director                                               cast  \
# 950   Peter Jackson  Mark Wahlberg, Rachel Weisz, Susan Sarandon, S...
# 8404  Peter Jackson  Elijah Wood, Ian McKellen, Liv Tyler, Viggo Mo...
# 8405  Peter Jackson  Elijah Wood, Ian McKellen, Liv Tyler, Viggo Mo...
#
#                                          country       date_added  \
# 950   United States, United Kingdom, New Zealand      May 1, 2021
# 8404                  New Zealand, United States  January 1, 2020
# 8405                  New Zealand, United States  January 1, 2020
#
#       release_year rating duration  \
# 950           2009  PG-13  136 min
# 8404          2003  PG-13  201 min
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# ascending order, smallest to largest
df.sort_values("release_year")[0:5]
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4250                          NaN                        NaN            NaN
# 7790                  Frank Capra                        NaN  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                        NaN  United States
# 8739  Frank Capra, Anatole Litvak                        NaN  United States
#
#              date_added  release_year rating  duration  \
# ...

# %%
# decending order, largest to smallest
df.sort_values("release_year", ascending=False)[0:5]
# Out:
#     show_id     type                                  title        director  \
# 693    s694    Movie                 Ali & Ratu Ratu Queens  Lucky Kuswandi
# 781    s782    Movie  Black Holes | The Edge of All We Know   Peter Galison
# 762    s763    Movie                           Sweet & Sour   Lee Kae-byeok
# 763    s764  TV Show                            Sweet Tooth             NaN
# 764    s765    Movie           Trippin' with the Kandasamys   Jayan Moodley
#
#                                                   cast        country  \
# 693  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...            NaN
# 781                                                NaN            NaN
# 762          Jang Ki-yong, Chae Soo-bin, Jung Soo-jung    South Korea
# 763  Nonso Anozie, Christian Convery, Adeel Akhtar,...  United States
# 764  Jailoshini Naidoo, Maeshni Naicker, Madhushan ...   South Africa
#
#         date_added  release_year rating  duration  \
# ...

# %%
# decending order, multiple columns
df.sort_values(["release_year", "date_added"], ascending=False)[0:5]
# Out:
#    show_id     type                                     title  \
# 88     s89    Movie  Blood Brothers: Malcolm X & Muhammad Ali
# 91     s92    Movie                The Women and the Murderer
# 92     s93  TV Show                            Into the Night
# 93     s94    Movie                                      JJ+E
# 95     s96  TV Show                                The Circle
#
#                               director  \
# 88                       Marcus Clarke
# 91  Mona Achache, Patricia Tourancheau
# 92                                 NaN
# 93                     Alexis Almström
# 95                                 NaN
#
#                                                  cast  \
# 88                            Malcolm X, Muhammad Ali
# 91                                                NaN
# 92  Pauline Etienne, Laurent Capelluto, Stefano Ca...
# 93  Elsa Öhrn, Mustapha Aarab, Jonay Pineda Skalla...
# 95                                    Michelle Buteau
#
# ...

# %%
# drop a column
df_no_id = df.drop(columns=["show_id"])
df_no_id.head(2)
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# export data
df_titles = df["title"]
df_titles.to_csv("titles.csv")
df_titles.to_excel("titles.xlsx")

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# Filter
df_movies = df[df['type'] =='Movie']
df_movies.head(5)
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
# Filter
df_tv_show = df[df['type'] =='TV Show']
df_tv_show.head(5)
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# Duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# Removoe duplicates
df.drop_duplicates()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Removoe duplicates inplace
df.drop_duplicates(inplace=True)

# %%
# Show null values for each columns
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Check data types
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Count Occurences for the release_year column
df['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1966       1
# 1925       1
# 1947       1
# 1959       1
# 1961       1
# Name: release_year, Length: 74, dtype: int64

# %%
# bar plot for first 10 values
df['release_year'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
# TV Show vs. Movie
df.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
# Filter
df_movies_in_2000 = df[(df['type'] =='Movie') & (df['release_year'] == 2000)]

# %%
df_movies_in_2000
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
# Filter
df['country'].value_counts()
df[(df['country'] =='South Korea') & (df['type'] =='Movie')]
# Out:
#      show_id   type                               title         director  \
# 556     s557  Movie                       The 8th Night    Kim Tae-hyung
# 762     s763  Movie                        Sweet & Sour    Lee Kae-byeok
# 1085   s1086  Movie                   Night in Paradise   Park Hoon-jung
# 1342   s1343  Movie                      Space Sweepers      Jo Sung-hee
# 1412   s1413  Movie                            Wish You      Sung Do-jun
# 1468   s1469  Movie           What Happened to Mr. Cha?     Kim Dong-kyu
# 1643   s1644  Movie                            The Call   Lee Chung-hyun
# 2036   s2037  Movie                              #Alive           Cho Il
# 2215   s2216  Movie              The Larva Island Movie  Ahn Byoung-wook
# 2410   s2411  Movie  The Witch: Part 1 - The Subversion   Park Hoon-jung
# 2650   s2651  Movie                        Time to Hunt   Yoon Sung-hyun
# 3308   s3309  Movie                    Tune in for Love      Jung Ji-woo
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
# Drop null values
data_not_null = df.dropna()

# %%
data_not_null.shape
# Out:
# (5332, 12)

# %%
# Filter by cast
data_not_null[data_not_null['cast'].str.contains('Leonardo DiCaprio')]
# Out:
#      show_id   type                        title           director  \
# 329     s330  Movie          Catch Me If You Can   Steven Spielberg
# 340     s341  Movie                    Inception  Christopher Nolan
# 392     s393  Movie             Django Unchained  Quentin Tarantino
# 1358   s1359  Movie               Shutter Island    Martin Scorsese
# 1469   s1470  Movie  What's Eating Gilbert Grape    Lasse Hallström
# 6272   s6273  Movie             Before the Flood     Fisher Stevens
# 6826   s6827  Movie            Gangs of New York    Martin Scorsese
# 7865   s7866  Movie           Revolutionary Road         Sam Mendes
# 8272   s8273  Movie                 The Departed    Martin Scorsese
#
#                                                    cast  \
# 329   Leonardo DiCaprio, Tom Hanks, Christopher Walk...
# 340   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 392   Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# ...

# %%
df.groupby(["type"], as_index=False).agg(count=pd.NamedAgg(column="type", aggfunc="count"))
# Out:
#       type  count
# 0    Movie   6131
# 1  TV Show   2676

# %%
df.groupby(["type"], as_index=False).count()
# Out:
#       type  show_id  title  director  cast  country  date_added  release_year  \
# 0    Movie     6131   6131      5943  5656     5691        6131          6131
# 1  TV Show     2676   2676       230  2326     2285        2666          2676
#
#    rating  duration  listed_in  description
# 0    6129      6128       6131         6131
# 1    2674      2676       2676         2676

# %%
df.groupby(["type"]).count()
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie       6131   6131      5943  5656     5691        6131          6131
# TV Show     2676   2676       230  2326     2285        2666          2676
#
#          rating  duration  listed_in  description
# type
# Movie      6129      6128       6131         6131
# TV Show    2674      2676       2676         2676
